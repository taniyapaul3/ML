# %% [markdown]
# <a href="https://colab.research.google.com/github/VIAMRSH123/ML-Lab/blob/main/Lab-1/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Lab-1

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder

df = pd.read_csv("Dataset of Diabetes .csv")
print("Original Shape:", df.shape)

num_cols = df.select_dtypes(include=np.number).columns
cat_cols = df.select_dtypes(exclude=np.number).columns

print("\nNumeric Columns:", list(num_cols))
print("Categorical Columns:", list(cat_cols))

df[num_cols] = df[num_cols].replace(0, np.nan)
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])
    df[col] = LabelEncoder().fit_transform(df[col])

print("\nMissing Values After Cleaning:")
print(df.isnull().sum())

Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df[num_cols] < (Q1 - 1.5 * IQR)) |
          (df[num_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

print("\nShape After Outlier Removal:", df.shape)

X = df.iloc[:, :-1]
y = df.iloc[:, -1]

print("\nFeature Shape:", X.shape)
print("Target Shape:", y.shape)

minmax = MinMaxScaler()
X_minmax = minmax.fit_transform(X)
print("\nMin-Max Normalization Applied")

standard = StandardScaler()
X_standard = standard.fit_transform(X)
print("Standardization Applied")

print("\nFinal Preprocessing Completed Successfully ✅")
# Out:
# Original Shape: (1000, 14)
#
# Numeric Columns: ['ID', 'No_Pation', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI']
# Categorical Columns: ['Gender', 'CLASS']
#
# Missing Values After Cleaning:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64
#
# Shape After Outlier Removal: (629, 14)
#
# Feature Shape: (629, 13)
# Target Shape: (629,)
#
# Min-Max Normalization Applied
# Standardization Applied
#
# Final Preprocessing Completed Successfully ✅
